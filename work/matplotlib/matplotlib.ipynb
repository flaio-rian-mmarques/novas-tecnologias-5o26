# %% [markdown]
# # Tipos de gráficos com matplotlib

# %% [markdown]
# ### Importar bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Carregar dados das chuvas

# %%
df = pd.read_csv("./matplotlib/rain-data.csv", parse_dates=["data"])
